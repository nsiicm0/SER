# %% [markdown]
# # Introduction

# %% [markdown]
# Do not spend too much time trying to get very tiny metrics improvement. Once you have a model with a correct predictive power, you should better spend time explaining your data cleaning & preparation pipeline as well as explanations & visualizations of the results.
#
# The goal is to see your fit with our company culture & engineering needs, spending 50h on an over-complicated approach will not give you bonus points compared to a simple, yet effective, to-the-point solution.

# %% [markdown]
# ## About the data

# %% [markdown]
# The dataset you will be working with is called Emo-DB and can be found [here](http://emodb.bilderbar.info/index-1280.html).
#
# It is a database containing samples of emotional speech in German. It contains samples labeled with one of 7 different emotions: Anger, Boredom, Disgust, Fear, Happiness, Sadness and Neutral.
#
# Please download the full database and refer to the documentation to understand how the samples are labeled (see "Additional information")
#
# The goal of this project is to develop a model which is able to **classify samples of emotional speech**. Feel free to use any available library you would need, but beware of re-using someone else's code without mentionning it!

# %% [markdown]
# ## Deliverable

# %% [markdown]
# The end-goal is to deliver us a zip file containing:
# * This report filled with your approach, in the form of an **iPython Notebook**.
# * A **5-10 slides PDF file**, containing a technical presentation covering the important aspects of your work
# * A Dockerfile which defines a container for the project. The container should handle everything (download the data, run the code, etc...). When running the container it should expose the jupyter notebook on one port and expose a Flask API on another one. The Flask app contains two endpoints:
#   - One for training the model
#   - One for querying the last trained model with an audio file of our choice in the dataset
# * A README.md which should contain the commands to build and run the docker container, as well as how to perform the queries to the API.
# * Any necessary .py, .sh or other files needed to run your code.

# %% [markdown]
# ```
#     AUTHOR: Niclas Simmler
#     DATE: April 22-29, 2021
# ```

# %% [markdown]
# # Libraries Loading

# %% [markdown]
# First, we will need to do some basic setup. We will activate autoreload and make sure the src code is visible in jupyter.

# %%
# %load_ext autoreload
# %autoreload 2
# %config Application.log_level="INFO"
import os
import sys

PROJECT_BASE_PATH = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
DATA_BASE_PATH = os.path.join(PROJECT_BASE_PATH, 'data')
MODEL_BASE_PATH = os.path.join(PROJECT_BASE_PATH, 'model')
SRC_BASE_PATH = os.path.join(PROJECT_BASE_PATH, 'src')
sys.path.insert(0, SRC_BASE_PATH)

from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# Let's load our required modules.
#
# We start of with our very own `ser` module. This one will hold all relevant functionalities.

# %%
import ser
from ser.utils import one_hot_encode, plot_conf_mat, score_clf, plot_history

# %% [markdown]
# Next, we will load some other common modules which we need.

# %%
import numpy as np
import pandas as pd
from matplotlib import cm
from pydub import AudioSegment
from pydub.playback import play
from pydub.utils import db_to_float, ratio_to_db
import matplotlib.pyplot as plt
from speechpy.feature import mfcc
import sklearn
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# # Data Preparation & Cleaning
#
# ## Download
#
# We will first need to download the data if not already done so. In order to deal with all the logic, a wrapper class will be used, which allows for easy operation on the dataset.
#
# The code for the dataset wrapper can be found in `src/ser/dataset.py`. First, instantiate a dataset object.

# %%
dataset = ser.Dataset(data_path=DATA_BASE_PATH, remote_url='http://emodb.bilderbar.info/download/download.zip')
# Out:
# 2021-04-29 12:02:47,232 - ser.dataset - INFO - Creating Dataset Wrapper object.
# 2021-04-29 12:02:47,233 - ser.dataset - INFO - > Base Path at "/Users/nik/Code/visium/data"
# 2021-04-29 12:02:47,234 - ser.dataset - INFO - > Pristine Path at "/Users/nik/Code/visium/data/pristine"
# 2021-04-29 12:02:47,234 - ser.dataset - INFO - > Working Path at "/Users/nik/Code/visium/data/working"
# 2021-04-29 12:02:47,235 - ser.dataset - INFO - Make sure that the http://emodb.bilderbar.info/download/download.zip points to a ZIP file.

# %%
# Run this line below if you want to clean the data directory
#dataset.clean()

# %% [markdown]
# Then we download the data.

# %%
dataset.download()
# Out:
# 2021-04-29 12:02:47,344 - ser.dataset - INFO - Dataset downloaded.
# True

# %% [markdown]
# The return value of the download is `True`, thus, everything went fine. If we were to rerun this function, it would not download anything anymore. However, using the `force=True` argument, we can initiate the download again.
#
# Since it is a ZIP File, we will need to extract it.

# %%
dataset.extract()
# Out:
# 2021-04-29 12:02:47,395 - ser.dataset - INFO - Dataset extracted.
# True

# %% [markdown]
# The extraction went well too. If we were to rerun this function, it would not extract anything anymore. However, using the `force=True` argument, we can initiate the extraction again.
#
# Now we need to parse the data. For this, let's have a look at the documentation (http://www.emodb.bilderbar.info/index-1280.html)
#
# In our data folder, we have multiple files and folders. Not all of them are relevant.

# %%
print(os.listdir(os.path.join(DATA_BASE_PATH, 'working')))
print(os.listdir(os.path.join(DATA_BASE_PATH, 'working', 'wav'))[:10])
# Out:
# ['wav', '.gitkeep', 'silb', 'erklaerung.txt', 'lablaut', 'erkennung.txt', 'labsilb']
# ['16a02Lb.wav', '14a07Wc.wav', '10a07Ad.wav', '13a05Ea.wav', '14a05Wa.wav', '14a07Na.wav', '15a05Wa.wav', '16b10Wb.wav', '09a01Nb.wav', '16a01Fc.wav']

# %% [markdown]
# For the task at hand, only the content of the `wav` folder are relevant. It contains wav-files that are named in the following schema (according to the documentation.
#
# ```
# Positions 1-2: number of speaker
# Positions 3-5: code for text
# Position 6: emotion (sorry, letter stands for german emotion word)
# Position 7: if there are more than two versions these are numbered a, b, c ....
# ```
#
# The documentation further states information about the speakers:
#
# ```
# 03 - male, 31 years old
# 08 - female, 34 years
# 09 - female, 21 years
# 10 - male, 32 years
# 11 - male, 26 years
# 12 - male, 30 years
# 13 - female, 32 years
# 14 - female, 35 years
# 15 - male, 25 years
# 16 - female, 31 years
# ```
#
# And about the spoken sample:
#
# |code|text (german)|try of an english translation|
# |--- |--- |--- |
# |a01|Der Lappen liegt auf dem Eisschrank.|The tablecloth is lying on the frigde.|
# |a02|Das will sie am Mittwoch abgeben.|She will hand it in on Wednesday.|
# |a04|Heute abend könnte ich es ihm sagen.|Tonight I could tell him.|
# |a05|Das schwarze Stück Papier befindet sich da oben neben dem Holzstück.|The black sheet of paper is located up there besides the piece of timber.|
# |a07|In sieben Stunden wird es soweit sein.|In seven hours it will be.|
# |b01|Was sind denn das für Tüten, die da unter dem Tisch stehen?|What about the bags standing there under the table?|
# |b02|Sie haben es gerade hochgetragen und jetzt gehen sie wieder runter.|They just carried it upstairs and now they are going down again.|
# |b03|An den Wochenenden bin ich jetzt immer nach Hause gefahren und habe Agnes besucht.|Currently at the weekends I always went home and saw Agnes.|
# |b09|Ich will das eben wegbringen und dann mit Karl was trinken gehen.|I will just discard this and then go for a drink with Karl.|
# |b10|Die wird auf dem Platz sein, wo wir sie immer hinlegen.|It will be in the place where we always store it.|
#
# And lastly, some information about the emotions:
#
# |letter|emotion (english)|letter|emotion (german)|
# |--- |--- |--- |--- |
# |A|anger|W|Ärger (Wut)|
# |B|boredom|L|Langeweile|
# |D|disgust|E|Ekel|
# |F|anxiety/fear|A|Angst|
# |H|happiness|F|Freude|
# |S|sadness|T|Trauer|
#
# Note: `N` is also an option which stands for `Neutral`.
#
# So, the sample `16a02Lb.wav` can be parsed as the following:
#
# * Speaker = 16 - female, 31 years
# * Text = a02 for "Das will sie am Mittwoch abgeben."
# * Emotion = L for "Langeweile"
# * Version = b (i.e., there is at least another version a in the dataset)

# %%
speakers = ['03', '08', '09', '10', '11', '12', '13', '14', '15', '16']
texts = ['a01', 'a02', 'a04', 'a05', 'a07', 'b01', 'b02', 'b03', 'b09', 'b10']
emotions = {
    'W': 'Ärger (Wut)',
    'L': 'Langeweile',
    'E': 'Ekel',
    'A': 'Angst',
    'F': 'Freude',
    'T': 'Trauer',
    'N': 'Neutral'
}
files = list()
for filename in os.listdir(os.path.join(dataset.working_path, 'wav')):
    assert len(filename) == 11, 'Encountered unknown filename.'
    _speaker = filename[0:2]
    assert _speaker in speakers, 'Encountered unknown speaker.'
    _text = filename[2:5]
    assert _text in texts, 'Encountered unknown text.'
    _emotion = filename[5:6]
    assert _emotion in emotions.keys(), 'Encountered unknown emotion.'
    _version = filename[6:7]
    assert _version in list('abcdefghijklmnopqrstuvwxyz'), 'Encountered unknown version.'
    files.append({
        'filename': filename,
        'full_path': os.path.join(dataset.working_path, 'wav', filename),
        'speaker': _speaker, 
        'text': _text,
        'emotion': _emotion,
        'version': _version
    })
print(files[:5])
# Out:
# [{'filename': '16a02Lb.wav', 'full_path': '/Users/nik/Code/visium/data/working/wav/16a02Lb.wav', 'speaker': '16', 'text': 'a02', 'emotion': 'L', 'version': 'b'}, {'filename': '14a07Wc.wav', 'full_path': '/Users/nik/Code/visium/data/working/wav/14a07Wc.wav', 'speaker': '14', 'text': 'a07', 'emotion': 'W', 'version': 'c'}, {'filename': '10a07Ad.wav', 'full_path': '/Users/nik/Code/visium/data/working/wav/10a07Ad.wav', 'speaker': '10', 'text': 'a07', 'emotion': 'A', 'version': 'd'}, {'filename': '13a05Ea.wav', 'full_path': '/Users/nik/Code/visium/data/working/wav/13a05Ea.wav', 'speaker': '13', 'text': 'a05', 'emotion': 'E', 'version': 'a'}, {'filename': '14a05Wa.wav', 'full_path': '/Users/nik/Code/visium/data/working/wav/14a05Wa.wav', 'speaker': '14', 'text': 'a05', 'emotion': 'W', 'version': 'a'}]

# %% [markdown]
# In order to get a more manageable interface for the samples, the `Sample` class is meant to interface a sample and deals with all low level operations.

# %%
s = ser.Sample(os.path.join(dataset.working_path, 'wav', '14a07Wc.wav'))
print(s)
# Out:
# <Sample name=14a07Wc.wav, path=/Users/nik/Code/visium/data/working/wav/14a07Wc.wav, length=None, sample_rate=None, speaker=14, gender=Female, text=a07, emotion=W, version=c, chunk=1>

# %% [markdown]
# As this seems to work, the dataset function `.prepare()` is meant to automate this.

# %%
dataset.prepare()
print(dataset.get_raw_data()[:2])
# Out:
# 2021-04-29 12:02:47,614 - ser.dataset - INFO - Dataset prepared.
# [<Sample name=16a02Lb.wav, path=/Users/nik/Code/visium/data/working/wav/16a02Lb.wav, length=None, sample_rate=None, speaker=16, gender=Female, text=a02, emotion=L, version=b, chunk=1>, <Sample name=14a07Wc.wav, path=/Users/nik/Code/visium/data/working/wav/14a07Wc.wav, length=None, sample_rate=None, speaker=14, gender=Female, text=a07, emotion=W, version=c, chunk=1>]

# %%
print(len(dataset.get_raw_data()))
# Out:
# 535

# %% [markdown]
# We got 535 samples in total. This is not an awful lot to work with. Thus, we might use some data augmentation method later on to increase the sample amount.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# As a next step, we will need to load the actual data. We need to keep in mind that the samples might be of different lengths. We have two options here: Either cut all samples to the smallest size OR padd all samples to the longest size. Since, we do not have that much data, it makes sense to not further reduce the dataset. Thus, we will apply some padding. But first, let's load some samples and see with what we are dealing with.

# %%
samples = dataset.get_raw_data()[:10]
for sample in samples:
    audio = AudioSegment.from_wav(sample.get('path'))
    print(audio.frame_rate, len(audio), audio)
# Out:
# 16000 2081 <pydub.audio_segment.AudioSegment object at 0x143f5a978>
# 16000 2064 <pydub.audio_segment.AudioSegment object at 0x143f5a9e8>
# 16000 1603 <pydub.audio_segment.AudioSegment object at 0x143f5aa90>
# 16000 4196 <pydub.audio_segment.AudioSegment object at 0x143f5aac8>
# 16000 4007 <pydub.audio_segment.AudioSegment object at 0x143f5ab38>
# 16000 2096 <pydub.audio_segment.AudioSegment object at 0x143f5aba8>
# 16000 3098 <pydub.audio_segment.AudioSegment object at 0x143f5ac18>
# 16000 2522 <pydub.audio_segment.AudioSegment object at 0x143f5ac88>
# 16000 1683 <pydub.audio_segment.AudioSegment object at 0x143f5acf8>
# 16000 2096 <pydub.audio_segment.AudioSegment object at 0x143f5ad68>

# %% [markdown]
# As we can see (second column), the files have a lot of different lengths. Thus, the padding is really necessary.

# %%
loaded_samples = list()
sample_lengths = list()
for sample in dataset.get_raw_data():
    audio = AudioSegment.from_wav(sample.get('path'))
    loaded_samples.append((audio.frame_rate, audio))
    sample_lengths.append(len(audio))

# %%
avg_length = int(round(sum(sample_lengths)/len(sample_lengths), 0))
print(f'Min length: {min(sample_lengths)}, Max length: {max(sample_lengths)}, Avg length: {avg_length}')
# Out:
# Min length: 1226, Max length: 8978, Avg length: 2780

# %%
plt.clf()
plt.hist(sample_lengths)
plt.xlabel('Sample length [ms]')
# Out:
# Text(0.5, 0, 'Sample length [ms]')

# %% [markdown]
# The length of the samples varies quite a lot. I expected it to be more densly packed. Given the fact that we are not dealing with an awful lot of data and that the sample lengths vary quite a lot, we will need to be careful when padding/slicing the audio. Since, we intend to use techniques such as MFCCs (Mel-frequency cepstral coefficients), the length of the sample is quite decisive. Too short and too long of a sample (i.e., < 1s and > few seconds) might not catch all features. Thus, we will proceed in the following manner:
#
# * Split each sample into chunk of length `min(sample_lengths)` (= this length might be a hyper-parameter for finetuning)
# * Create new samples based on additional chunks
# * Pad the last sample with silence
#
# This way we will end up with a lot more samples (which is good, since we haven't had that many samples to start with). The last sample might not be really helpful in case it only contains a few milliseconds of information and is padded with a lot of noise.
#
# It is worth noting: It might be that our length is too small, thus we would need to be able to increase this length and fine tune. We will consult research later on to find an ideal length candidate.

# %%
def split_and_pad(sample, length):
    sample_length = len(sample)
    delta = length - sample_length
    chunks = list()
    if delta < 0: # sample needs splitting
        chunks.extend(sample[::length])
    else:
        chunks.append(sample)
    # pad the last chunk
    last_chunk = chunks[-1]
    to_pad = length - len(last_chunk)
    padding = AudioSegment.silent(duration=to_pad, frame_rate=last_chunk.frame_rate)
    # combine the samples and also make sure we really do not exceed the length due to rounding issues
    chunks[-1] = last_chunk.append(padding, crossfade=0)[:length]
    return chunks

# %%
for i, chunk in enumerate(split_and_pad(loaded_samples[1][1], min(sample_lengths))):
    print(f'Playing chunk #{i+1}')
    #play(chunk) # uncomment to play
# Out:
# Playing chunk #1
# Playing chunk #2

# %% [markdown]
# Another thing of concern might be the normalization. We are dealing with audio samples from Male and Female, spoken in different emotions and of different sentences. Naturally, the audio amplitude will vary based on the source. Thus, it seems relevant to normalize the audio prior to feature extraction to achieve an unbiased representation.
#
# Let's have a look at a few examples:

# %%
def plot_wave_form(samples):
    fig, axs = plt.subplots(len(samples), 1, figsize=(10, 3*len(samples)))
    fig.tight_layout(pad=3.0)
    for ax, sample in zip(axs, samples):
        audio_buffer = np.frombuffer(sample.get_array_of_samples(), dtype=np.int16)
        audio_len = len(sample)
        time = np.linspace(0, audio_len, num = len(audio_buffer))
        ax.plot(time, audio_buffer)
        ax.set_title(f'Length: {audio_len}, Amplitude Max: {sample.max}, Amplitude Max DB: {sample.max_dBFS}')
    plt.show()

# %%
male = None
female = None
first_text = None
# Find a female and male sample
for sample in dataset.get_raw_data():
    if male is not None and female is not None:
        break
    if sample.get('speaker') in ['03', '10', '11', '12', '15']:
        if first_text is None or sample.get('text') != first_text:
            if male is None:
                male = AudioSegment.from_wav(sample.get('path'))
        else:
            continue
    else:
        if first_text is None or sample.get('text') != first_text:
            if female is None:
                female = AudioSegment.from_wav(sample.get('path'))
        else:
            continue

# %%
plot_wave_form([male, female])

# %% [markdown]
# It does not appear to be a crazy difference in amplitude. But better be safe than sorry.

# %%
def find_peak_amplitude(samples):
    max_value = -np.inf
    max_dbfs = -np.inf
    for _, sample in samples:
        max_value = sample.max if max_value < sample.max else max_value
        max_dbfs = sample.max_dBFS if max_dbfs < sample.max_dBFS else max_dbfs
    return (max_value, max_dbfs)
        
max_value, max_dbfs = find_peak_amplitude(loaded_samples)

# %%
def normalize(sample, max_value, headroom=0.1):
    """Normalize function.
    Based on implementation of pydub: https://github.com/jiaaro/pydub/blob/master/pydub/effects.py#L36-L49
    """
    target_peak = sample.max_possible_amplitude * db_to_float(-headroom)
    needed_boost = ratio_to_db(target_peak / max_value)
    return sample.apply_gain(needed_boost)

# %%
plot_wave_form([normalize(sample, max_value) for sample in [male, female]])

# %% [markdown]
# Unfortunately, the normalization does not make much of a difference (the numbers only differ because we applied some headroom). However, in light of a possible application with unseen data, the normalization step is mandatory for data samples outside of the dataset. Furthermore, the Emo-DB dataset was recorded in a professional recording studio [1]. We can expect quite good audio processing from the samples.
#
# The dataset function `.load()` is meant to automate this whole process.

# %%
#avg = lambda x: int(round(sum(x)/len(x), 0))
dataset.load(split_at=min)
# Out:
# 2021-04-29 12:02:49,665 - ser.dataset - INFO - Normalizing requested.
# 2021-04-29 12:02:49,782 - ser.dataset - INFO - Dataset loaded.
# True

# %%
print('Samples: ', len(dataset.get_loaded_data()))
dataset.get_loaded_data()[:10]
# Out:
# Samples:  1484
# [<Sample name=16a02Lb.wav, path=/Users/nik/Code/visium/data/working/wav/16a02Lb.wav, length=1226, sample_rate=16000, speaker=16, gender=Female, text=a02, emotion=L, version=b, chunk=1>,
#  <Sample name=16a02Lb.wav, path=/Users/nik/Code/visium/data/working/wav/16a02Lb.wav, length=1226, sample_rate=16000, speaker=16, gender=Female, text=a02, emotion=L, version=b, chunk=2>,
#  <Sample name=14a07Wc.wav, path=/Users/nik/Code/visium/data/working/wav/14a07Wc.wav, length=1226, sample_rate=16000, speaker=14, gender=Female, text=a07, emotion=W, version=c, chunk=1>,
#  <Sample name=14a07Wc.wav, path=/Users/nik/Code/visium/data/working/wav/14a07Wc.wav, length=1226, sample_rate=16000, speaker=14, gender=Female, text=a07, emotion=W, version=c, chunk=2>,
#  <Sample name=10a07Ad.wav, path=/Users/nik/Code/visium/data/working/wav/10a07Ad.wav, length=1226, sample_rate=16000, speaker=10, gender=Male, text=a07, emotion=A, version=d, chunk=1>,
#  <Sample name=10a07Ad.wav, path=/Users/nik/Code/visium/data/working/wav/10a07Ad.wav, length=1226, sample_rate=16000, speaker=10, gender=Male, text=a07, emotion=A, version=d, chunk=2>,
#  <Sample name=13a05Ea.wav, path=/Users/nik/Code/visium/data/working/wav/13a05Ea.wav, length=1226, sample_rate=16000, speaker=13, gender=Female, text=a05, emotion=E, version=a, chunk=1>,
#  <Sample name=13a05Ea.wav, path=/Users/nik/Code/visium/data/working/wav/13a05Ea.wav, length=1226, sample_rate=16000, speaker=13, gender=Female, text=a05, emotion=E, version=a, chunk=2>,
#  <Sample name=13a05Ea.wav, path=/Users/nik/Code/visium/data/working/wav/13a05Ea.wav, length=1226, sample_rate=16000, speaker=13, gender=Female, text=a05, emotion=E, version=a, chunk=3>,
#  <Sample name=13a05Ea.wav, path=/Users/nik/Code/visium/data/working/wav/13a05Ea.wav, length=1226, sample_rate=16000, speaker=13, gender=Female, text=a05, emotion=E, version=a, chunk=4>]

# %% [markdown]
# We now have a lot more samples, plus, we can also see with the `chunk` information, that we have multiple samples for the same file if it exceeds the length specified for the split. Also, all samples are now of the same length.
#
# Next up, is the feature extraction. Here in lies the actual work. According to various research [2, 3, 4] , a common feature is the MFCC.
# I will first implement the MFCC but will make it modular so we can easily extend it later on.
# Thankfully, the MFCC extraction is implemented in the `speechpy` library. Since we are using pydub.AudioSegments, we will first need to convert them to format that is understandable by speechpy.

# %%
samples = dataset.get_loaded_data()[3:5]
samples
# Out:
# [<Sample name=14a07Wc.wav, path=/Users/nik/Code/visium/data/working/wav/14a07Wc.wav, length=1226, sample_rate=16000, speaker=14, gender=Female, text=a07, emotion=W, version=c, chunk=2>,
#  <Sample name=10a07Ad.wav, path=/Users/nik/Code/visium/data/working/wav/10a07Ad.wav, length=1226, sample_rate=16000, speaker=10, gender=Male, text=a07, emotion=A, version=d, chunk=1>]

# %%
def extract_coefficients(samples, coefficients=13):
    fig, axs = plt.subplots(len(samples), 1, figsize=(15,1*len(samples)), sharey=True)
    #fig.tight_layout(pad=3.0)
    mfccs = list()
    for ax, sample in zip(axs, samples):
        np_chunk = np.frombuffer(sample.get('object').get_array_of_samples(), dtype=np.int16)
        mel_coefficients = mfcc(np_chunk, sample.get('sample_rate'), num_cepstral=coefficients)
        mfccs.append(np.ravel(mel_coefficients)) # we flatten the data
        mfcc_data = np.swapaxes(mel_coefficients, 0, 1) # we are swapping axis for horizontal visualization
        cax = ax.imshow(mfcc_data, interpolation='nearest', cmap=cm.coolwarm, origin='lower') 
        ax.set_ylabel('Coefficients')
    fig.suptitle('MFCC', fontsize='20')
    plt.xlabel('Time')
    plt.show()
    print('Coefficients Shape:', mfccs[0].shape)
    return mfccs

# %%
mfccs = extract_coefficients(samples)
# Out:
# Coefficients Shape: (1560,)

# %% [markdown]
# This particular sample's MFCC look a bit weird, as we have a lot of activity in the first chunk, but almost nothing in the second one. Let's listen whether this makes sense. (Hint: Yes it does)
# Also, we can see the padding in the second half of the second subplot.
#
# One thing to note: The coefficients parameter defines the num_cepstral in the mfcc function. In research, between 10-20 is considered a good amount of features for speech analysis [5]. Obviously, the higher the number, the more "depth" we will gain in the features, but it will also make our models more complex (which is not good).

# %%
for i, sample in enumerate(samples):
    print(f'Playing chunk #{i+1}')
    #play(sample.get('object')) # uncomment to play
# Out:
# Playing chunk #1
# Playing chunk #2

# %% [markdown]
# Another set of features we should not let go to waste are the information regarding the gender and spoken text. Both feature subset will be one-hot encoded.
#
# The dataset function `.feature_extract()` is meant to automate this whole process of feature extraction. It can also easily be extended as demonstrated below.
#
# We will first only extract the features of gender and spoken text. After that I will demonstrate how easily extendable the feature extraction process is by re-exctracting the features including the MFCCs.

# %%
dataset.feature_extract(
    extraction_methods={'SpeakerAndGenderAndTextType': (ser.SpeakerAndGenderAndTextTypeFeatureExtractor, {'speaker':True, 'gender': True, 'text': True})}
)
print('Features:', dataset.get_features()[0].shape)
# Out:
# 2021-04-29 12:02:50,276 - ser.dataset - INFO - Now extracting features using SpeakerAndGenderAndTextType Feature Extractor
# 2021-04-29 12:02:50,331 - ser.dataset - INFO - Feature extracted.
# Features: (1484, 22)

# %%
dataset.feature_extract(
    extraction_methods={
        'SpeakerAndGenderAndTextType': (ser.SpeakerAndGenderAndTextTypeFeatureExtractor, {'speaker':True, 'gender': True, 'text': True}), 
        'MFCC': (ser.MFCCFeatureExtractor, {'num_cepstral':13})
    },
    force=True
)
print('Features:', dataset.get_features()[0].shape)
# Out:
# 2021-04-29 12:02:50,380 - ser.dataset - INFO - Forcing feature extraction. Flushes X, y variable.
# 2021-04-29 12:02:50,381 - ser.dataset - INFO - Now extracting features using SpeakerAndGenderAndTextType Feature Extractor
# 2021-04-29 12:02:50,447 - ser.dataset - INFO - Now extracting features using MFCC Feature Extractor
# 2021-04-29 12:02:55,460 - ser.dataset - INFO - Feature extracted.
# Features: (1484, 1582)

# %% [markdown]
# ### Closing notes on features:
#
# Additional features could be:
#
# * Mel Spectrogram (could be used to feed a CNN)
# * Spectral Contrast as seen in [6]
#
# In order to implement further feature extractors, one would only need to implement an additional `ser.FeatureExtractor` class.

# %% [markdown]
# # Modeling & Results & Visualizations
#
# After the feature extraction, a couple of modeling approaches come to mind. The different approaches will be analyzed in the following cells.
# First, we will need to get our training and testing data.

# %%
X, y = dataset.get_features()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# We will first test a basic classifier to get an initial feeling to start. The `RandomForestClassifier` will not perform well and shall by no means be a serious modeling approach, it only serves to get a basic understanding of the API.
#
# We are dealing with an awful lot of features, thus we will be applying PCA prior to the training to reduce the components to learn.
# For the training we will be using a custom Pipeline that is build on the sklearn Pipeline class. The Pipeline class allows the stacking of PCA and a Classifier in one go. This custom pipeline is derived from the custom BaseModel which offers convenience functions to save and restore a model. Thus, we can save PCA and the Classifier easily and load it back after the training for prediction.

# %%
pca = PCA(n_components=500)
clf = RandomForestClassifier(n_estimators=100)

pipe = ser.Pipeline(save_path=MODEL_BASE_PATH, steps=[('pca', pca), ('clf', clf)])
pipe.fit(X_train, y_train)
# Out:
# 2021-04-29 10:54:13,891 - ser.model - INFO - Instantiated a SERPipeline model with name WZldM5mSt3hxJ7Ck.
# SERPipeline(init_pipeline=None, name='WZldM5mSt3hxJ7Ck',
#             save_path='/Users/nik/Code/visium/model',
#             steps=[('pca', PCA(n_components=500)),
#                    ('clf', RandomForestClassifier())])

# %% [markdown]
# Saving of the model is easy.

# %%
pipe.save_model()
# Out:
# 2021-04-29 10:54:16,594 - ser.model - INFO - Saved to /Users/nik/Code/visium/model/WZldM5mSt3hxJ7Ck.pkl

# %% [markdown]
# Same goes for the loading back into action.

# %%
mdl = ser.Pipeline.load_from_name(save_path=MODEL_BASE_PATH, name='WZldM5mSt3hxJ7Ck', steps=[])
# Out:
# 2021-04-29 10:54:20,886 - ser.model - INFO - Instantiated a SERPipeline model with name WZldM5mSt3hxJ7Ck.

# %% [markdown]
# Let's see how the training went.

# %%
score_clf(mdl, X_test, y_test, clazzes_mapping=emotions, is_from_gridsearch=False)
# Out:
#               precision    recall  f1-score   support
#
#        Angst       0.00      0.00      0.00        20
#         Ekel       0.00      0.00      0.00        19
#       Freude       0.25      0.05      0.09        19
#   Langeweile       0.26      0.41      0.32        17
#      Neutral       0.50      0.21      0.30        19
#       Trauer       0.62      0.64      0.63        28
#  Ärger (Wut)       0.34      0.93      0.50        27
#
#     accuracy                           0.37       149
#    macro avg       0.28      0.32      0.26       149
# weighted avg       0.30      0.37      0.29       149

# %% [markdown]
# Since we are dealing with a lot of classes with different levels of representation, we cannot just utilize the accuracy score, but need to have a look at other metrics such as Precision and Recall (or the combination of the two in F1-score).
#
# Despite treating the RandomForestClassifier as no serious approach, let's still have a look at it.
# It seems that we are "really" good at predicting "Ärger (Wut)" (engl. Anger) as well as "Trauer" (engl. Sadness). We predicted 25 out of 27 samples correctly (thus, the high recall of 0.93) as Anger and 18 out of 28 as Sadness. However, we predicted an awful lot of other classes (Angst, Ekel, Freude) as Anger (thus, the low precision of 0.34). Sadness performed a bit more average in precision and recall. Thus, Sadness was classifier better overall than Anger (F1 score of 0.63 vs 0.5).
# The other classes were really poorly predicted, thus we continue our search for a modeling approach.
#
# As a first serious modeling approach, we will be using XGBoost, which is a notoriously well performing ML model.

# %%
pca = PCA(n_components=500)
clf = XGBClassifier(n_estimators=100)

pipe = ser.Pipeline(save_path=MODEL_BASE_PATH, steps=[('pca', pca), ('clf', clf)])
pipe.fit(X_train, y_train)
# Out:
# 2021-04-29 10:54:28,970 - ser.model - INFO - Instantiated a SERPipeline model with name 7vergVPDlNpWTXzi.
# [10:54:29] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# SERPipeline(init_pipeline=None, name='7vergVPDlNpWTXzi',
#             save_path='/Users/nik/Code/visium/model',
#             steps=[('pca', PCA(n_components=500)),
#                    ('clf',
#                     XGBClassifier(base_score=0.5, booster='gbtree',
#                                   colsample_bylevel=1, colsample_bynode=1,
#                                   colsample_bytree=1, gamma=0, gpu_id=-1,
#                                   importance_type='gain',
#                                   interaction_constraints='',
#                                   learning_rate=0.300000012, max_delta_step=0,
#                                   max_depth=6, min_child_weight=1, missing=nan,
#                                   monotone_constraints='()', n_estimators=100,
#                                   n_jobs=8, num_parallel_tree=1,
#                                   objective='multi:softprob', random_state=0,
#                                   reg_alpha=0, reg_lambda=1,
#                                   scale_pos_weight=None, subsample=1,
#                                   tree_method='exact', validate_parameters=1,
#                                   verbosity=None))])

# %%
score_clf(pipe, X_test, y_test, clazzes_mapping=emotions, is_from_gridsearch=False)
# Out:
#               precision    recall  f1-score   support
#
#        Angst       0.20      0.10      0.13        20
#         Ekel       0.78      0.37      0.50        19
#       Freude       0.33      0.16      0.21        19
#   Langeweile       0.29      0.53      0.38        17
#      Neutral       0.38      0.32      0.34        19
#       Trauer       0.59      0.57      0.58        28
#  Ärger (Wut)       0.47      0.81      0.59        27
#
#     accuracy                           0.44       149
#    macro avg       0.43      0.41      0.39       149
# weighted avg       0.45      0.44      0.41       149

# %% [markdown]
# This looks a lot better already than our RandomForestClassifier. The main difference seems to be that overall we see better performance in most classes. Especially, interesting is the class Ekel (engl. Disgust), which we previously never correctly classified, and now we get up to a precision of 0.78. Also, the recall of Anger is now a lot better because we do not mistake that many other classes as Anger anymore. Unfortunately, we loose some confidence in predicting Anger (lower precision).
#
# As a next modeling approach, we will trial some different parameters for XGBoost. Mainly, the No. of estimators might have an influence on the performance. For this we can use the sklearn GridSearchCV object, that will trial different parameter configurations and selects the best model.

# %%
pca = PCA(n_components=500)
clf = XGBClassifier()

pipe = ser.Pipeline(save_path=MODEL_BASE_PATH, steps=[('pca', pca), ('clf', clf)])

param_grid = {
    'clf__n_estimators': [10, 50, 150]
}

search = GridSearchCV(pipe, param_grid, n_jobs=-1, cv=2)
search.fit(X_train, y_train)
print(f'Best parameter (CV score={search.best_score_:.3f}): {search.best_params_}')
# Out:
# 2021-04-29 11:53:58,537 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:53:58,541 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:53:58,545 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:53:58,547 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:53:58,549 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:53:58,551 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:53:58,552 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:53:58,554 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:54:33,803 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# 2021-04-29 11:54:33,807 - ser.model - INFO - Instantiated a SERPipeline model with name 79dBOSefuazVKzrg.
# [11:54:34] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best parameter (CV score=0.356): {'clf__n_estimators': 150}

# %%
score_clf(search, X_test, y_test, clazzes_mapping=emotions, is_from_gridsearch=True)
# Out:
#               precision    recall  f1-score   support
#
#        Angst       0.11      0.05      0.07        20
#         Ekel       0.58      0.37      0.45        19
#       Freude       0.44      0.21      0.29        19
#   Langeweile       0.28      0.41      0.33        17
#      Neutral       0.29      0.26      0.28        19
#       Trauer       0.62      0.57      0.59        28
#  Ärger (Wut)       0.45      0.85      0.59        27
#
#     accuracy                           0.42       149
#    macro avg       0.40      0.39      0.37       149
# weighted avg       0.41      0.42      0.39       149

# %% [markdown]
# We found the best set of parameters to be `n_components = 150`. However, the performance does not seem to drastically improve.
#
# As a next approach, we will trial a neural network built using Keras. There are tons of parameters to tune with a neural network, however, for this exercise, we will only focus on training duration (epoch count) and batch_size. Also note, to reduce the amount of parameters to train (since we do not have that many training samples), we will lower the input size using PCA to a 100 components.

# %%
input_dim = 100
pca = PCA(n_components=input_dim)
clf = ser.KerasClassifier(build_fn=lambda: ser.KerasClassifier.build_base(n_classes=len(emotions), lr=0.001, input_dim=input_dim, dropout=0.2), verbose=0)
y_test_onehot = one_hot_encode(y_test, emotions.keys())

pipe = ser.Pipeline(save_path=MODEL_BASE_PATH, steps=[('pca', pca), ('clf', clf)])

param_grid = {
    'clf__epochs': [10, 30, 50, 70, 90, 110],
    'clf__batch_size': [32, 64, 96]
}

search = GridSearchCV(pipe, param_grid, n_jobs=-1, cv=2)
search.fit(X_train, y_train, clf__validation_data=(pca.fit_transform(X_test), y_test_onehot))

print(f'Best parameter (CV score={search.best_score_:.3f}): {search.best_params_}')
# Out:
# 2021-04-29 12:03:00,874 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,936 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,954 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,958 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,960 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,961 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,963 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,964 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,966 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:00,967 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:01,109 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:01,134 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:01,139 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:01,145 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:01,147 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:01,149 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:01,151 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:01,153 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:12,035 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:12,037 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:12,040 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:12,042 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:12,045 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:12,047 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:12,049 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:12,051 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:18,276 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:18,278 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:18,286 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:18,289 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:18,292 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:18,294 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:18,297 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:18,299 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:24,760 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:24,763 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:24,771 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:24,774 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:37,392 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:37,395 - ser.model - INFO - Instantiated a SERPipeline model with name RsbIgaCCcVmQHPEn.
# 2021-04-29 12:03:37,774 - ser.model - INFO - Model: "sequential"
# 2021-04-29 12:03:37,775 - ser.model - INFO - _________________________________________________________________
# 2021-04-29 12:03:37,776 - ser.model - INFO - Layer (type)                 Output Shape              Param #
# 2021-04-29 12:03:37,777 - ser.model - INFO - =================================================================
# 2021-04-29 12:03:37,778 - ser.model - INFO - dropout (Dropout)            (None, 100)               0
# 2021-04-29 12:03:37,779 - ser.model - INFO - _________________________________________________________________
# 2021-04-29 12:03:37,780 - ser.model - INFO - dense (Dense)                (None, 100)               10100
# 2021-04-29 12:03:37,781 - ser.model - INFO - _________________________________________________________________
# 2021-04-29 12:03:37,782 - ser.model - INFO - dropout_1 (Dropout)          (None, 100)               0
# 2021-04-29 12:03:37,782 - ser.model - INFO - _________________________________________________________________
# 2021-04-29 12:03:37,783 - ser.model - INFO - dense_1 (Dense)              (None, 7)                 707
# 2021-04-29 12:03:37,784 - ser.model - INFO - =================================================================
# 2021-04-29 12:03:37,785 - ser.model - INFO - Total params: 10,807
# 2021-04-29 12:03:37,786 - ser.model - INFO - Trainable params: 10,807
# 2021-04-29 12:03:37,787 - ser.model - INFO - Non-trainable params: 0
# 2021-04-29 12:03:37,788 - ser.model - INFO - _________________________________________________________________
# Best parameter (CV score=0.406): {'clf__batch_size': 96, 'clf__epochs': 110}

# %% [markdown]
# We can also have a look at the training history, which tells us something about over-/underfitting during training.
# Note: We can also extract such curves from other models such as XGBoost, but for the sake of simplicity, we are not looking into this.

# %%
plot_history(search.best_estimator_.named_steps['clf'].hist)

# %% [markdown]
# When looking at the training curves (dashed), it seems that the best parameter selection of 110 epochs could have been further increased because the accuracy curve is still rising.
# Also, we do not seem to have overfitting of model (must be probably because of our applied dropout). We are technically still underfitting since the validation accuracy does not seem to match the training accuracy.

# %%
score_clf(search, X_test, y_test, clazzes_mapping=emotions, is_from_gridsearch=True)
# Out:
# 2021-04-29 12:07:02,166 - tensorflow - WARNING - From /Users/nik/.pyenv/versions/3.6.11/lib/python3.6/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py:241: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#               precision    recall  f1-score   support
#
#        Angst       0.00      0.00      0.00        20
#         Ekel       0.73      0.42      0.53        19
#       Freude       0.39      0.37      0.38        19
#   Langeweile       0.34      0.59      0.43        17
#      Neutral       0.47      0.37      0.41        19
#       Trauer       0.69      0.64      0.67        28
#  Ärger (Wut)       0.59      0.74      0.66        27
#
#     accuracy                           0.47       149
#    macro avg       0.46      0.45      0.44       149
# weighted avg       0.48      0.47      0.46       149

# %% [markdown]
# The model performance seems to have improved quite a lot (the diagonal is more pronounced than before). Despite everything, our model was not able to predict any of the Angest (engl. Fear) samples correctly.
#
# After all these approaches, it seems that the model currently mostly recognizes the loudness of the samples. I.e., Anger and Sadness are louder than Fear and Happiness. Thus, it is easier for the model to recognize those, but harder to distinguish the others. An additional feature extractor that quantifies the loudness/power of the audio might be helpful.
#
# ### Closing notes on modeling:
#
# In these modeled approaches, I did not pay attention to the optimization using grid search. Obviously, in a more ellaborate modeling, close attention would need to be paid onto which metric grid search optimizes for.
#
# Since we are dealing with a audio data, which inherently has a time dependency, a possible further modeling solution would be to utilize an LSTM model.
# The approaches presented here mostly showcase the way the `ser` module works, but it would be straightforward to implement another build_fn analgous to `build_base` that generates a Keras LSTM model.

# %% [markdown]
# # References

# %% [markdown]
# [1] Burkhardt, F., Paeschke, A., Rolfes, M., Sendlmeier, W. F., & Weiss, B. (2005). A database of German emotional speech. In Ninth European Conference on Speech Communication and Technology.
#
# [2] Sezgin, M.C., Gunsel, B. & Kurt, G.K. Perceptual audio features for emotion detection. J AUDIO SPEECH MUSIC PROC. 2012, 16 (2012). https://doi.org/10.1186/1687-4722-2012-16
#
# [3] Ayadia ME, Kamelb MS, Karrayb F: Survey on speech emotion recognition: features, classification schemes, and databases. Pattern Recognit 2011, 44(3):572-587.
#
# [4] Ververidis D, Kotropoulos C: Emotional speech recognition: resources, features, and methods. Speech Commun 2006, 48(9):1162-1181.
#
# [5] Poorjam, Amir Hossein. (2018). Re: Why we take only 12-13 MFCC coefficients in feature extraction?. Retrieved from: https://www.researchgate.net/post/Why_we_take_only_12-13_MFCC_coefficients_in_feature_extraction/5b0fd2b7cbdfd4b7b60e9431/citation/download.
#
# [6] Dan-Ning Jiang, Lie Lu, Hong-Jiang Zhang, Jian-Hua Tao and Lian-Hong Cai, "Music type classification by spectral contrast feature," Proceedings. IEEE International Conference on Multimedia and Expo, 2002, pp. 113-116 vol.1, doi: 10.1109/ICME.2002.1035731.
